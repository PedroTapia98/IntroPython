# %% [markdown]
# # **Ejercicio1 - Utilizar operadores aritméticos**

# %% [markdown]
# ## Operadores aritméticos en Python

# %% [markdown]
# Python proporciona operadores aritméticos comunes para que puedas realizar operaciones matemáticas en tu código. Estos incluyen las cuatro operaciones principales de suma, resta, multiplicación y división.
#
# Exploremos cómo podemos crear un programa que pueda calcular la distancia entre dos planetas. Comenzaremos usando dos distancias de planetas: Tierra (149.597.870 km) y Júpiter (778.547.200 km).

# %% [markdown]
# ## Solucíon

# %%
#Definimos las variables
Planeta1 =  149597870 
Planeta2 = 778547200

# %%
#Aplicamos la diferencia para hallar la distancia
distancia_km = Planeta2 - Planeta1
print('Distancia en km= ',distancia_km)

#Para convertir de km a millas 
distancia_millas = distancia_km*0.621
print('Distancia en millas= ',distancia_millas)
# Out:
# Distancia en km=  628949330
# Distancia en millas=  390577533.93

# %% [markdown]
# ##Ejercicio 2: convierte cadenas en números y usa valores absolutos

# %% [markdown]
# ###Crear una aplicación para trabajar con números y entrada de usuario

# %% [markdown]
# Con frecuencia, deberás convertir los valores de cadena en números para realizar correctamente diferentes operaciones o determinar el valor absoluto de un número.
#
# Para crear nuestra aplicación, queremos leer la distancia del sol para dos planetas, y luego mostrar la distancia entre los planetas. Haremos esto usando input para leer los valores, int para convertir a entero y luego abs para convertir el resultado en su valor absoluto.

# %% [markdown]
# ###Lee los valores
# Usando input, agrega el código para leer la distancia del sol para cada planeta, considerando 2 planetas.
#
# #
#
# ```
# # Almacenar las entradas del usuario
# #Pista: variable = input("¿Cuál es tu nombre?")
# ```
#
# ###Convertir a número
# Debido a que input devuelve valores de cadena, necesitamos convertirlos en números. Para nuestro ejemplo, usaremos int
#
#
# ```
# # Convierte las cadenas de ambos planetas a números enteros
# ```
#
# ###Realizar el cálculo y convertir a valor absoluto
# Con los valores almacenados como números, ahora puedes agregar el código para realizar el cálculo, restando el primer planeta del segundo. Debido a que el segundo planeta podría ser un número mayor, usarás abs para convertirlo a un valor absoluto. También agregarás el código para mostrar el resultado en millas multiplicando la distancia del kilómetro por 0.621
#
# ### Realizar el cálculo y det
#
# ```
# # Realizar el cálculo y determinar el valor absoluto
# # Convertir de KM a Millas
# ```
#
# ###Prueba tu aplicación
# Para probar el proyecto, ejecuta tu notebook. En la parte superior de vscode surgirá un cuadro de diálogo para que proporciones las distancias. Puede utilizar los datos de la tabla siguiente:
#
# | Planeta |Distacia al Sol |
# |----------|----------------|
# | Mercurio | 57900000 |
# |Venus | 108200000 |
# |Tierra | 149600000 |
# |Marte | 227900000 |
# |Júpiter | 778600000 |
# |Saturno | 1433500000 |
# | Urano | 2872500000 |
# |Neptuno | 4495100000 |

# %% [markdown]
# # Solución

# %%
#Almacenamos las entradas del usuario
Planeta1 = input('Introduzca la distancia del sol al primer planeta en km')
Planeta2 = input('IntroIntroduzca la distancia del sol al segundo planeta en km')
# Out:
# Introduzca la distancia del sol al primer planeta en km57900000
# IntroIntroduzca la distancia del sol al segundo planeta en km108200000

# %%
#Cambiar a números enteros
Planeta1 = int(Planeta1)
Planeta2 = int(Planeta2)

# %%
#Realizar el cálculo y aplicar el valor absoluto
distancia_km = Planeta2 - Planeta1
print('Distancia en kilometros=',distancia_km)

#Conversion a millas
distancia_millas = distancia_km*0.621
print('Distancia en millas=',distancia_millas)
# Out:
# Distancia en kilometros= 50300000
# Distancia en millas= 31236300.0
